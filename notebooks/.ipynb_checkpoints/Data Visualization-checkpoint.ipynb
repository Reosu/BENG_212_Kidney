# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from scipy.sparse import csr_matrix
from matplotlib.lines import Line2D

# %%
from sklearn import cluster, metrics
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import umap
from sklearn.manifold import TSNE

# %%
# Data was filtered to preserve one sample type per experimental condition 
data = pd.read_csv("../data/filtered_data.csv",index_col=0)

# %%
Supp_data2 = pd.read_excel('../metadata/filtered_metadata.xls',skiprows=4,usecols = range (1,32))
Supp_data2
# Out:
#    Experiment Library Library Barcode     PPID   Specimen ID  \
# 0    20161122     NK5            N705     3351      K1600543
# 1   20171016A     NK9            N703     3395      K1700233
# 2   20171016C    NK13            N705     3395      K1700233
# 3   20171214D    NK21            N720     3432      K1700578
# 4   20171214A    NK25            N706     3431      K1700572
# 5   20180123C    NK27            N711     3435      K1800017
# 6   20180123C    NK28            N712     3435      K1800017
# 7   20180123D    NK29            N714     3435      K1800017
# 8   20180123D    NK30            N715     3435      K1800017
# 9   20180123A    NK31            N716     3434      K1800010
# 10  20180131A    NK35            N721     3431      K1700573
# 11  20180207F    NK41            N714     3414      K1700443
# 12  20180207H    NK44            N720     3414      K1700442
# 13  20180413B    NK49            N703     3444      K1800105
# 14  20180328A    NK55            N711     3395      K1700234
# 15  20180328C    NK59            N716     3411      K1700432
# 16  20180424A    NK64            N722  17-1606  17-1606-3-M4
# 17  20180430A    NK71            N701   18-162   18-162-3-M2
# 18  20180430F    NK81            N714   18-162   18-162-3-M2
#
#                 Sample                                 Tissue Treatment  \
# 0           K1600543_2                                 RNAlater 6 Hours
# 1           K1700233_8  Flash Frozen, Cryosection (35umx7) OCT embedded
# 2           K1700233_9                                 RNAlater 6 Hours
# 3          K1700578_12                   60 minutes Trypsin-Collagenase
# 4          K1700572_11                    30 minutes Papain-Collagenase
# 5         K1800017_5FB      Dry-ice frozen, 5x40uM Sections - Wisc Soln
# 6         K1800017_5FB      Dry-ice frozen, 5x40uM Sections - Wisc Soln
# 7         K1800017_5FB       Dry-ice frozen, 5x40uM Sections - RNAlater
# 8         K1800017_5FB       Dry-ice frozen, 5x40uM Sections - RNAlater
# 9           K1800010_4         30 minutes Papain-Collagenase - RNAlater
# 10         K1700573_FB                 Dry-ice frozen, 10x40uM Sections
# 11        K1700443_7FB     Dry-ice frozen, 10x40uM Sections - Wisc Soln
# 12       K1700442_12FB      Dry-ice frozen, 10x40uM Sections - RNAlater
# 13        K1800105-4FB       Dry-ice frozen, 7x40uM Sections - RNAlater
# 14         K1700234-fb       Dry-ice frozen, 7x40uM Sections - RNAlater
# 15         K1700432-fb                  Dry-ice frozen, 7x40uM Sections
# 16  UMich_17-1606-3-M4                 Liquid Nitrogen, 7x40uM Sections
# 17   UMich-18-162-3-M2                  Dry-ice frozen, 7x40uM Sections
# 18   UMich-18-162-3-M2       Dry-ice frozen, 7x40uM Sections - RNAlater
#
#    Tissue Treatment (Short) Tissue Collection (Short)  \
# 0                  RNAlater               Nephrectomy
# 1               Cryosection               Nephrectomy
# 2                  RNAlater               Nephrectomy
# 3       Trypsin-Collagenase               Nephrectomy
# 4        Papian-Collagenase               Nephrectomy
# 5          Cryosection-Wisc               Nephrectomy
# 6          Cryosection-Wisc               Nephrectomy
# 7      Cryosection-RNAlater               Nephrectomy
# 8      Cryosection-RNAlater               Nephrectomy
# 9        Papian-Collagenase               Nephrectomy
# 10              Cryosection               Nephrectomy
# 11         Cryosection-Wisc                     Donor
# 12     Cryosection-RNAlater                     Donor
# 13     Cryosection-RNAlater               Nephrectomy
# 14     Cryosection-RNAlater               Nephrectomy
# 15              Cryosection               Nephrectomy
# 16              Cryosection               Nephrectomy
# 17              Cryosection               Nephrectomy
# 18     Cryosection-RNAlater               Nephrectomy
#
#    Nuclei Extraction Protocol  ... % Coding  % UTR  % Intronic  % Intergenic  \
# 0                  NEB/Dounce  ...     8.84   3.59       48.93         38.64
# 1                  NEB/Dounce  ...    24.09   3.79       39.66         32.47
# 2                  NEB/Dounce  ...    20.06   2.41       46.48         31.06
# 3                  NEB/Dounce  ...    60.45   8.89       23.44          7.22
# 4                  NEB/Dounce  ...    41.23   8.85       41.79          8.12
# 5                  NEB/Dounce  ...    57.78   9.69       24.74          7.79
# 6                  NEB/Dounce  ...    55.14   9.85       26.96          8.05
# 7                  NEB/Dounce  ...    38.00  10.64       43.98          7.38
# 8                  NEB/Dounce  ...    37.18  10.65       44.77          7.40
# 9                  NEB/Dounce  ...    32.07   6.38       53.40          8.15
# 10                 NEB/Dounce  ...    53.34   8.69       30.56          7.41
# 11                 NEB/Dounce  ...    43.28   7.23       38.48         11.00
# 12                 NEB/Dounce  ...    53.58   8.48       24.11         13.83
# 13                 NEB/Dounce  ...    55.70   4.76       24.88         14.66
# 14                 NEB/Dounce  ...    37.77   5.76       37.39         19.08
# 15                 NEB/Dounce  ...    52.80   5.80       28.91         12.49
# 16                 NEB/Dounce  ...    46.46   5.10       34.64         13.79
# 17                 NEB/Dounce  ...    38.58   6.30       44.57         10.56
# 18                 NEB/Dounce  ...    33.08   5.72       52.87          8.33
#
#          % MT  Post QC (>400 nonMT UMI; >400 <5000 nonMT Genes Detected).1  \
# 0    0.476256                                                 80
# 1   17.118767                                                741
# 2    4.356989                                                177
# 3   24.998104                                                782
# 4    2.907478                                                350
# 5   29.062712                                                177
# 6   26.754064                                                193
# 7    3.451212                                                197
# 8    2.854999                                                188
# 9    1.965794                                                147
# 10  24.435342                                                443
# 11  12.001749                                               1017
# 12  20.076799                                                562
# 13  43.773523                                                 50
# 14   9.336564                                                188
# 15  30.792483                                                210
# 16   7.065217                                                  4
# 17   6.103458                                                212
# 18   2.647129                                                931
#
#     Used for Clustering Analysis  Useful reads        UMI  Duplication level
# 0                            yes      181896.0    92994.0           0.488752
# 1                            yes     1516531.0   753643.0           0.503048
# 2                            yes      275203.0   150365.0           0.453622
# 3                            yes     1054658.0   738702.0           0.299581
# 4                            yes     1684831.0   406276.0           0.758862
# 5                            yes     1086360.0   284369.0           0.740000
# 6                            yes     1451490.0   308772.0           0.790000
# 7                            yes     1666541.0   275335.0           0.830000
# 8                            yes     1385188.0   241267.0           0.830000
# 9                            yes      720470.0   125326.0           0.830000
# 10                           yes     1138300.0   734017.0           0.360000
# 11                           yes     2552183.0  1104870.0           0.570000
# 12                           yes     1065762.0   517712.0           0.510000
# 13                           yes      112217.0    42899.0           0.620000
# 14                           yes      196534.0   123764.0           0.370000
# 15                           yes      315737.0   198994.0           0.370000
# 16                            no           NaN        NaN                NaN
# 17                           yes      362842.0   140173.0           0.610000
# 18                           yes     1208156.0   579418.0           0.520000
#
# [19 rows x 31 columns]

# %%
labels = pd.DataFrame()
groups = Supp_data2.groupby("Library")
colors = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple',
              'tab:brown','tab:pink','tab:gray','tab:olive', 'tab:cyan',
              'black', 'salmon', 'chocolate', 'orange', 'gold', 'lawngreen',
              'turquoise', 'steelblue', 'navy', 'violet', 'deeppink',
              'firebrick', 'sandybrown','olivedrab','darkgreen', 'aqua',
              'slategray', 'blue', 'fuschia', 'pink']
c_map = {}
num=0
for i,j in groups:
    c_map.update({i:colors[num]})
    num+=1
data_colors = []
for i in data.columns:
    data_colors.append(c_map[i.split("_")[1]])

# %%
# Non-standard normalization in order to preserve sparsity, as z-scores fail to execute
# due to mathematical error of dividing by zero
scaler = StandardScaler(with_mean=False)
scaler.fit(data.transpose())
norm_data = scaler.transform(data.transpose())
    
pca= PCA(150).fit(norm_data)
pca_transform = pca.fit_transform(norm_data)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.18002533738741552

# %%
factor_analysis = FactorAnalysis(150).fit(norm_data)
fa_transform = factor_analysis.fit_transform(norm_data)

# %%
fit = umap.UMAP()
# %time u = fit.fit_transform(pca_transform)
# Out:
# CPU times: user 34 s, sys: 1.04 s, total: 35.1 s
# Wall time: 18.5 s

# %%
fig,ax = plt.subplots(figsize=[20,20])
ax.scatter(u[:,0],u[:,1],c=data_colors)

custom_lines = []
for i,j in c_map.items():
    custom_lines.append(Line2D([0], [0], color=j, lw=4))
ax.legend(custom_lines,list(c_map.keys()),bbox_to_anchor=(1, 1), loc='upper left',fontsize=14)

# %%
# %time tsne = TSNE(n_components=2).fit_transform(pca_transform)
# Out:
# CPU times: user 1min 59s, sys: 115 ms, total: 1min 59s
# Wall time: 20.8 s

# %%
fig,ax = plt.subplots(figsize=[20,20])
ax.scatter(tsne[:,0],tsne[:,1],c=data_colors)
custom_lines = []
for i,j in c_map.items():
    custom_lines.append(Line2D([0], [0], color=j, lw=4))
ax.legend(custom_lines,list(c_map.keys()),bbox_to_anchor=(1, 1), loc='upper left',fontsize=14)
